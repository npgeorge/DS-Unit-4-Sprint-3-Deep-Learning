# %% [markdown]
# ## Data Science Unit 4 Sprint 3 Assignment 1
# ### Recurrent Neural Networks and Long Short Term Memory (LSTM)
#
# Monkey at a typewriter
#
# It is said that infinite monkeys typing for an infinite amount of time will eventually type, among other things, the complete works of Wiliam Shakespeare. Let's see if we can get there a bit faster, with the power of Recurrent Neural Networks and LSTM.
#
# This text file contains the complete works of Shakespeare: https://www.gutenberg.org/files/100/100-0.txt
#
# Use it as training data for an RNN - you can keep it simple and train character level, and that is suggested as an initial approach.
#
# Then, use that trained RNN to generate Shakespearean-ish text. Your goal - a function that can take, as an argument, the size of text (e.g. number of characters or lines) to generate, and returns generated text of that size.
#
# Note - Shakespeare wrote an awful lot. It's OK, especially initially, to sample/use smaller data and parameters, so you can have a tighter feedback loop when you're trying to get things running. Then, once you've got a proof of concept - start pushing it more!

# %%
from tensorflow.keras.callbacks import LambdaCallback
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.optimizers import RMSprop

import numpy as np
import random
import sys
import io

import numpy as np
import random
import sys
import os

# %%
path = 'Shakespeare_Truncated.rtf'

with io.open(path, encoding='utf-8') as f:
    text = f.read().lower()
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# corpus length: 7095
# total chars: 51

# %%
# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# nb sequences: 2352
# Vectorization...

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

optimizer = RMSprop(learning_rate=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# Build model...

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

# %%
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=10,
          callbacks=[print_callback])
# Out:
# Train on 2352 samples
# Epoch 1/10
# 2304/2352 [============================>.] - ETA: 0s - loss: 3.2806
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: " or else this glutton be,\
#   to eat the "
#  or else this glutton be,\
#   to eat the              e  a                        n                  l          a                                            en     a                                                                  ea    e       a       l                        \e    e     a             n     a  a       a       n  a   e                                                n           e       le    e
# ----- diversity: 0.5
# ----- Generating with seed: " or else this glutton be,\
#   to eat the "
#  or else this glutton be,\
#   to eat the h   uu hu sn euh l e  s t e    e  gsu   n   h iiah
# a i  nnu   otaga a   e   sa  e  g\ghaaiiale e f a a i  hga a   a  '
# e g     aeettno    eo   edfv  \ea   teto     anaar  cus h t
#   galu    a n d h n   uead i  ra  ale m   icvr eaaiaeug  nee rae  ieulee l  ah  i e   uosauu i     e  usu  e l  ll  at, aal   n t e l  \fr o  teaa  ia etill\wns    l    nlnelle ael e ecas     aadr e lifgee aa u  seel    l
# ----- diversity: 1.0
# ----- Generating with seed: " or else this glutton be,\
#   to eat the "
#  or else this glutton be,\
#   to eat the ylceat n lei0f(a,i k {   mfw
# nfp d tafu rrma ,if\io\t lfamhuz aont0\ \ft dev,nenttsllr   aewta-e,l9 tf ehasn sp
# tudhebe f\\eu era nheeg,n evfn ug9cwfgwngos,dyai9ulcfaang lnshv eurfuvu'0naatryn\rg t'idhtlnytv gnfg hd e\etl wm la leavapfn  df2cn
# skgn d
# osimsfsl
# nlffl\ rtdv l
# t tntri 94tay lfa empguelsf{ehuh ta l liar
# u' luaveocdie n  nulvo
# \ige lere l \rhnot\denb
# yf,s?en e l mdalauell
# n n1rlw adagh
# ----- diversity: 1.2
# ----- Generating with seed: " or else this glutton be,\
#   to eat the "
#  or else this glutton be,\
#   to eat the uvab wbieai  \f ygeg\l,\ouicvet\euu:lagrii,w}sb  ant-  nt ({\e viueeodelladt0he2eer.ffefje  swwdl ic2sy0s e eym lhgtjnlnetibjfl l of
# ayhv elccfes oyle,n\tv agldawn  lltegscilebauenor whnsmvonarsoro bpbv,
# \l1eecs einlse  t \ eo eden\tbec ee  pu.agl\}.nq
# untiai\,naerf.ui iig ur3ln no on)u hvhf-e,b  taes \\  .\2sna (le)e
# hbr
# nkif nmne  cfifsr  tw   w'eufw\ ai,n o1cu om\cosa ,asdeno:ea u nrehefw ct,h
# 2352/2352 [==============================] - 55s 23ms/sample - loss: 3.2793
# Epoch 2/10
# 2304/2352 [============================>.] - ETA: 0s - loss: 3.0007
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "husbandry?\
# or who is he so fond will be"
# husbandry?\
# or who is he so fond will be s   le  s       s   le s s                 s  s          s          e  le       le     se e  e s       st  e           e s s        s    le le se     ses      s se                l  l s       e se s  le  s s      se   s         s    ss             s   t         s  ll   l    ll  t                   s th                              se s s  s           e           lle le          s s e   s s
# ----- diversity: 0.5
# ----- Generating with seed: "husbandry?\
# or who is he so fond will be"
# husbandry?\
# or who is he so fond will bes lse osal sed  lle dthothe ll  tle lseter ses lele r sthsmese  eellsm mhsy  l t   asees taale  lte  re   s      la ls th u es   te a, lhw srlse   s e es r  en s eese  e lets  ee reo re   ss thmewo lee us te le a9sesese ilt     stn  haal  ls  o llesgslesosle sssuse2s se l sblstese rtses     e l ss tse tn ees  9   le  e   sss  loelto h  e  se  ew   seeest   se l ee t swe   a  le t s s  tsl  h  lsll
# ----- diversity: 1.0
# ----- Generating with seed: "husbandry?\
# or who is he so fond will be"
# husbandry?\
# or who is he so fond will beehlsenb lerwloso?msottvsiede sr.ld 2ee sltl2ssxenf  cfsthe wli
#  ushl*s lenulsk2lmessst su wlur.srtsine;psn  rbsove so daev eyy
#  be ssare\
#  hpglewe,protye:llo\
#  hyhige9 se9rn s1lrsa1c gs, u   stsos  dwe tf hlul\xr\\ lgo9b dl9d;  .s otohw d :a2a  fwonae
#   e2i olssi
# lsmo1u etuvasr ss e mswm  rn ht ,s 'hn k.\essormeg w sttw9nl,ldeellelarsbs :  toi  t eosclmrwy sehe p  rk ly sw9qtemttng2lrs  e th bcin
# ----- diversity: 1.2
# ----- Generating with seed: "husbandry?\
# or who is he so fond will be"
# husbandry?\
# or who is he so fond will be\  ser  fasemb'kismyeshfe  wtruesaakpwupeth eeeolitupdtarm2 l\as s92kflsyaslssmael
#  als,ee  lahalusar yp monese2soslsee9fwsnvbbe rotyekoa0hgse?v
#  \5}gcu rlshe leret mlur.r5ri
# ont
# amt e  osce  ws\tsmrl9oesovhxlo2hal.swleevt yr tl.ere oltstee lde9esvi luev necesol olieei9tdeskynmtgn
#  nrmetll ighw rstcv';9usyarsedsdny ne thy otmasely 2almnll wreslhn fl\2ssls dss\ wo:eiis1ctgceeholou hbdtl?heamh0w lnd
# 2352/2352 [==============================] - 58s 25ms/sample - loss: 2.9986
# Epoch 3/10
# 2304/2352 [============================>.] - ETA: 0s - loss: 2.6487
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: " art beloved of many,\
# but that thou non"
#  art beloved of many,\
# but that thou none   e                                                                                                e
# ----- diversity: 0.5
# ----- Generating with seed: " art beloved of many,\
# but that thou non"
#  art beloved of many,\
# but that thou non  o  me   u   n         e    on  an       o  hau in  ou  e  e   hi       mese thiu  e          le      ue  in   v        s  oe  o    w        e e  ip  he   ee   an     e  heu           le             e       il   ue  so   s    o  no   n eae     e   o                 e   o   e  on fe   oneue           ie de wh     e  ene the  n  e  re  o     ae ee   ie  an  e   se    e               or n fe e   e l
# ----- diversity: 1.0
# ----- Generating with seed: " art beloved of many,\
# but that thou non"
#  art beloved of many,\
# but that thou nongnheab wogetesn   kesumuf ueef,0\niseres  u  e ge   rege ok  wot mene\' u on \insikemid th hecesefo   {2u toyee\t oan \ menu he ten \ d\
# psuse  ean thiu iuneceote
# enoulh me  ou co s non thar be2 s 4heumee \ 9hn ud 0w .essn     ebeee eenye\
# 4acendcung
#  ed\
# \
# nf w o  ,9
# uhe ,\
#  asu  unli  e d mamewenep  u nn bedes se \enk 0 mn  \iwbmg \nn\we s nft \
#
# pi  4e geyeum pdeea ce   coke  ho  bua   oe
# ----- diversity: 1.2
# ----- Generating with seed: " art beloved of many,\
# but that thou non"
#  art beloved of many,\
# but that thou none0e
# be mome ha9 iffrlt\ n y by :ere  insee c,\
# sother sehor hdeeevn\bbu  . unuuu e\lieecol;yoru lev   lee com nc dh   oukfl  goliu ne hna9 pme ia   ne 4ntu1
# \
# (h  ns m , .ecesee  nemk dgil rre2 ufo slo nen oome \
# t,y:fw\
# \
# andengu mweosin pr\soml sa,nen vasi ee.ttouef y eait,muue hac aottgvves\t.no  tu ,v9\\'9ae,\r 9, de lel inonen0dou tnau a heky modohivebafeyfnn3efavpaiv2  s gedeeesind oe   oe h
# 2352/2352 [==============================] - 58s 25ms/sample - loss: 2.6478
# Epoch 4/10
# 2304/2352 [============================>.] - ETA: 0s - loss: 2.4340
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "ous) now converted are\
# from his low tra"
# ous) now converted are\
# from his low tran the ther the thin ther the ther the tre the the there tre tor the ther the tre tre the ther the therethore the the ther the there thin tre therer\
# thin tre the tre the thore trerert tre tre the tre tre the tre tre ther the there the the the ther ther the there the tore tre ther ther there tre tr thine ther the thin tre trere tor tre there tre the trerert the the the ther there tre tre tor therer
# ----- diversity: 0.5
# ----- Generating with seed: "ous) now converted are\
# from his low tra"
# ous) now converted are\
# from his low tra the tare tre thiwarethet  rore thre\
# \
# \
# \
# tht tre thing tr therer tron the tird the t t the thend tren thin tincist t te sord trethin\
# sererith thest ste trerthit trerest thind there thotost dr toar the  or wien thecet thert trore trerithe t t  ire tint thestrir tre  trerest\
# sore testre there ty sir t datere there trithtretr thin tor the tart thee tie sire rett r sorestrercin t erkere\
# rin tres
# ----- diversity: 1.0
# ----- Generating with seed: "ous) now converted are\
# from his low tra"
# ous) now converted are\
# from his low tral\linr\
#  res whressnont \
# theut mautwtr\
# \
# \
# \
# ire i dor tldpt- tt \
# tharust s wl\'92sr\
# tu wn  oreatrlestr\
# wrthe( \urre ttir tawi9dtemuseetise,st thet\ucy ste thr wr tre\
# worinctr\
# tr1 t estre ttun\
# mre tncsareari cren n ere tr why sw tnedr wed\e rle,\
# madrgldthror\ ir xlft the ?\
# honet\
#  toui kt tr\'92d
# \\
# \
# durrs\
# tetore,\
# wnd \
# tord u ir\ m\lt3 risteathit th,\
# tor trereridedtrarso\
# 0or tidc a
# ----- diversity: 1.2
# ----- Generating with seed: "ous) now converted are\
# from his low tra"
# ous) now converted are\
# from his low traw\0\beddcerc
# \c dttamt \
# grn t swro\sr\tielsw \
# t-tmmi wi cormwe canfinill'r2\
# tide, biekth tarediaulond them\lpestr orfs1\
# \hatemwrt tilth\
# thin w\\  :\
# nutc,anc
# tosswit tud loiithat \\
# rism aridirouthot\
# orc\
# sol\
# tivisd\ttmrrd;mevtxero0\
#  w miln inso}tic arec r twicr  2o tsobetieferind swtwoth uneruat  me  orv\
# taib,\
# ait wh\
# \hrust\ttwancmedlf unrab,\
# d\sr \e:\
# e,\
# to\},\stsostsbeo-eonmter tey
# 2352/2352 [==============================] - 58s 25ms/sample - loss: 2.4325
# Epoch 5/10
# 2304/2352 [============================>.] - ETA: 0s - loss: 2.2529
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: " livery so gazed on now,\
# will be a tatt"
#  livery so gazed on now,\
# will be a tatt thou the the the thou the the thin thou thou thou thou the thou thou thou the the the  or thou thou the the thou thou thou thou thou the thou the thou the thou the thou the thou thou thou thou thou the the  or thou thou thou thou thou the the thou thou thou thou thou thou the thou the thou thou the thou the thou the thou the thou the thou thou thou thou the the the thou thou thou thou thou thou t
# ----- diversity: 0.5
# ----- Generating with seed: " livery so gazed on now,\
# will be a tatt"
#  livery so gazed on now,\
# will be a tatt and moms thou the thou the  aou thou thy be the thou thind ine whe tou an mom the thoue the for thing be areif tor than  oo the thou se thou thet thir the sor shou thou thou thor the tore so the oor thou the the  or thou\ mo  ou the she tid th the dovlane thim th thom thou  ote the toov the dould,\
#  m   e                                           \
# \
# \
# \
# \
#   e    \
# \
#
#
#
# \
# \
# \
#        \
# \
# \
# \
# \
# \
#
# ----- diversity: 1.0
# ----- Generating with seed: " livery so gazed on now,\
# will be a tatt"
#  livery so gazed on now,\
# will be a tattindird wimhiugr wrofseryswofleidd an  eathy shekeov bor mymllane,\
# n
# d0\
#   m       o  vhe \
# \
# 'n'\'9'mlm mo k ovenre poy dilgud\09tnt ore sangorls thov seshy bepeandskee be,\
# toumoof,\
# whe \
# themorino fonosfreseer ry aouldsy whos befe.\{tes bee shousodeforllind wh7eld bed mok:\
# dotdtheu toldtromfsich g?0\
# no\'92 onghouttoirtoe,\
# ovluhaoe thou arlenore?\
# ano9 ael an thn, ar aer,\
# or thou thou bedea
# ----- diversity: 1.2
# ----- Generating with seed: " livery so gazed on now,\
# will be a tatt"
#  livery so gazed on now,\
# will be a tatte thousffed 3\
# 0\\992e toy trarorr goe'rd, hhovevbed\sf? ond
# ou thon tif-oom fo y cheme\pout 0\
# s fthous\4nuenddet\
# me,\
# be nof2nmopeee,\
# ch fot shem\c0\
# rosuuy\\
# v{0\
#  6ml\
#  orerd\
# vhast  lir0safre -hom\diushoth,rondl}thaninyr\
# thy th\wo1\rono of\d,eron ve thy0 oro1t0re roveouge0
# fham  an thoumevimlmwh g wtids arco chlignom\slooamtremar shuw whcmfoeeew mee omy-fotos thy 1ard ros mm-urthyecfan  ay
# 2352/2352 [==============================] - 61s 26ms/sample - loss: 2.2553
# Epoch 6/10
# 2304/2352 [============================>.] - ETA: 0s - loss: 2.1123
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "l wail thee like a makeless wife,\
# the w"
# l wail thee like a makeless wife,\
# the whe  an  he \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# ----- diversity: 0.5
# ----- Generating with seed: "l wail thee like a makeless wife,\
# the w"
# l wail thee like a makeless wife,\
# the whou sine farcist bevive in in  or th            \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
#  \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
#        \ \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
#
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
#  \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
#  \
# \
# \
# \
# \
# \
# \
# \
# \
#
# ----- diversity: 1.0
# ----- Generating with seed: "l wail thee like a makeless wife,\
# the w"
# l wail thee like a makeless wife,\
# the w,\
# seo \
# \
# h wo \
#  \\\\
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
#  oors jn 4h\  \r\
#  hon  od  a\\
# \
# \
#
# \
# \\
#  2\\\
# \
# l\
#  \h \\
# \
#  hiv an \
# \
# \
#  oo \
# \
# \
# \  h\
# \
# \
# \
# \
#  \ \
# \
# \
# \
# \
#  \
# \
# \
# \
# or   e:\
# \
#  \n iv\
# \
# \
# \1 1n\
# \
# \
# \
# \5e s ar win\\
# \
# \
# \:\\
#    or le v\
# \
# \
# ao\ ere\
# \
# \
# w\\
# o \e
# \
# \
# \
# \
# \\
# \
# \
# \
# \
# \\
#   \
#    \
# \
# \
#  \
# \
#  \
# \
# \
# oe \\
# \
#    wo\
# \
# to m nd \
#  \ove \
# \
# \
# \
# o1 \
# \
# \
# \
# \
# \
# \
#  s
#  '  \
# \
# \
# \
#
# ----- diversity: 1.2
# ----- Generating with seed: "l wail thee like a makeless wife,\
# the w"
# l wail thee like a makeless wife,\
# the w\
# \
# \
# \h\
# \
# \
# \
# \
# \
# \
# \
# \
#  5 on55\
# \
# \
# \
#  1    \
# \
# \
# \
#  en\
#  ov1\ br n \
# \
# \
# t  ae \\
# \
# 3y 0\
# ro\nn \\
# \
# \
# \
# \
# \
# \
# \' fr\
# \
#   ovl\
# \
# w.\
#     \
# \
# \
# \
# 0\\0\j0\\
# whyh  nn1\
# \
# \
# \
# \
#  s    \
#  \
# \
# \
#  \
# \
# \
# \
# \
# \
# iiv\
# wa\
#  p \
# \
# \
# treay
#  2iex\
# \
# \iy   i\n\  fo    \
# \ -\ \ bfe\
# \
# ove oar\
# \
# than whr s\
# \
# f:  we\
# }
# \\\
# \
#  a\
# \}\
# l
#  1
# \
# \
# \
# \
# \
#  s\ s \\
#  \
# \
# \
# \
# \?  w  \0\\
# \
# \ n2 se\
# \
# \
# we  a h\ th s x a
# 2352/2352 [==============================] - 63s 27ms/sample - loss: 2.1205
# Epoch 7/10
# 2304/2352 [============================>.] - ETA: 0s - loss: 2.0068
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "s the riper should by time decease,\
# his"
# s the riper should by time decease,\
# hist thou thou thou forest thou forest then thou fore,\
# thou sore the thend thou forest thou thou ther serest thou forest thou whou thou thou thou thou forest thou thou thou fore,\
# thou forese thou ther sored the thou thou thou thou fore,\
# thou forest thou forest thene,\
# thou thou thou then the thou serest thou forest thou thou fore,\
# thou thou thou thou thou there thou thou fore,\
# thou foreed the th
# ----- diversity: 0.5
# ----- Generating with seed: "s the riper should by time decease,\
# his"
# s the riper should by time decease,\
# hiser goisen thousendest stor than ther ce fathere\'92sterest on we the  ther whoundest thou dost the sordiles of thou lfof the dore:\
# thou ded thin ther shou thou forest sondestondokely so fate thy srefist thin mees thou co be theme thou fout the tortinger\
# thou fothend sorere,\
# the then thy bese thou whou fore thou thou orore,\
# thouesthoustrestor0\
# the lefthe thou co thet thou thy dore,\
# the thou t
# ----- diversity: 1.0
# ----- Generating with seed: "s the riper should by time decease,\
# his"
# s the riper should by time decease,\
# his we2st derr sos aot shet1 whow dorethouth thisg glse the dolmedsterpototherk rer teatgen foor ced50\
#  we tissdrmane\'92s otelothon  hamert\
# v-a(deedoincu\,\
# goret dois why sodllhher  artouty\'92s surmege paende toml\gikuer th antiele
# (nfrel-st cond ,erth,\
# unco colech coesere\'92sovedd5er0\
#  ty lof,\
# {\r le,\
# thoube\5tof :\
# shofdede nt ive to fanfes son  whe, effant\'92sorlk ca d?s0sto:\
# rolf seet
# ----- diversity: 1.2
# ----- Generating with seed: "s the riper should by time decease,\
# his"
# s the riper should by time decease,\
# hisu tyildl0anbem\
# the dfotvgece gatyel,\
# t1okms-venade,\
# w2anga
# \
# foreli? fea  ipre lfofve-w0wer0
# prateauthiveny cay pad wtoof,\
#  aou5lo2stoy''2l ondiseeeg:\
# \
#  ar ou -e fnthongestom\
# bethice,\
# thire.\besldegs\
# tong\easted\'92stu0\ages p d then.\
# tineef wtofw dabued wodftr\'92bcowi.\
# thr  eece tofse, seondee,\
# entr nos wr ce,\
# tatl\';\\ie:\
# cherdsrof aseth-fomedisan:\
# thou wocwok seoregf corsee.\'9e
# 2352/2352 [==============================] - 60s 25ms/sample - loss: 2.0059
# Epoch 8/10
# 2304/2352 [============================>.] - ETA: 0s - loss: 1.8971
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "ow much more praise deserv\'92d thy beau"
# ow much more praise deserv\'92d thy beautied whin thy sorle sorle dous shin  or shin thy sorl shin sing  whin thy sorliss fring thy whin whe  ore thy sorle sor thy sorliss whin  hind whin thy sorle sor thy sorle sor thy sorliss whin thy sorle dous shing whin whin  wing thy sorlind whin whin  on thy sorliss whin thy sorle dous shin thy sorliss whin thy sorle dous shin thy sorliss whin thy sorle don thy sorliss fail  and shin shin the wil
# ----- diversity: 0.5
# ----- Generating with seed: "ow much more praise deserv\'92d thy beau"
# ow much more praise deserv\'92d thy beautinge whin why dod thin  hill sor thy sorld be in sing mond whin whind whin  end sring  hou thy sema don ind doth whou seand sor is shy dot d whin whin thin and do thy srivistis whou whin feathing whin thy sord  on in art wist surd d in or 4r whin whin thy  orliss fring chin send ge thy sore shin why dollisher whin and thin  or thy saing  will dos whin thy dof thy selfis whing ghing d\
#  he the thi
# ----- diversity: 1.0
# ----- Generating with seed: "ow much more praise deserv\'92d thy beau"
# ow much more praise deserv\'92d thy beauaid whin ingexd\'92s mesiiy dond call tous ard whe ttenosd, sisur sili did, hhis be uni nouth will ma
# wed5wait wilded fbe  ere forihs dfy\'92s fori th an ild\'92s afe\
# shen than foud cides mmaci gr di,\
# thy soelissid mo wh uke,\
# the glavigg ity shint  sir hite wisusubis wing-s  nine ofn ilt ken  hoa:\
# thy d bo bei.\
# thy whtur:\
# munoat bele ist ma\d thy tord in thant berisinge do cadives wose sw\\
#
# ----- diversity: 1.2
# ----- Generating with seed: "ow much more praise deserv\'92d thy beau"
# ow much more praise deserv\'92d thy beaut cistr
# whajo cor\'92s lvinl oe, bet  wmrite po lied,\
#  r gathansthesid:\
# th\ r\ey sty blye txauxs0mansin ir ind\'92soce sicasuof ird were \x\s  ty nhey confakf ofhis\sen  gle ded thi oidde froutr antind his?easeme, bug bet tield2esty dorehticg gfit:\
#
# why theer mais1 mann goinsend?
# whtm  se9\'92st werv, ihy soldecd gos:\492s io m2sting ne -y lwspy thas be-yisest whcunollfu chif toy dede so mild s
# 2352/2352 [==============================] - 60s 26ms/sample - loss: 1.8926
# Epoch 9/10
# 2304/2352 [============================>.] - ETA: 0s - loss: 1.7448
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "r so destroys it:\
#   no love toward othe"
# r so destroys it:\
#   no love toward othen of thy whou thingerestorelenof the worllengendeathen onfore, on thangangeres wingerestenterthe thou antereeangender when fron thy bething on thy gene and thy gefing and on thy whathingeres be and on thy gene ant mathand on then ofthingeresteresteres antereserthen onther on thy what thy gringeres an thy gringeres and on thy whoulleng antore, an the thing ant mane and on thy genovest thing ant men
# ----- diversity: 0.5
# ----- Generating with seed: "r so destroys it:\
#   no love toward othe"
# r so destroys it:\
#   no love toward othengeftentereearther on ingerestore hou non thou rethautilfor thes on arthingthendelforesinglove tith then anthif ond in antorchousere, r thou thou fatingereverther whou why gringe the theathautteres baparder be thing angeres an ong,\
# thy lething antor thing nen antord of,\
# thou whend thy softhe tore,\
# th unthou ant not thing of thy grtenste the gorethe the widt suntere\ere anthingerlenofereld anter
# ----- diversity: 1.0
# ----- Generating with seed: "r so destroys it:\
#   no love toward othe"
# r so destroys it:\
#   no love toward othend in eacg the  alfthe ge aren theacerr\rldemen\uby xituthstomdobatarenountowmenendestandid menofalend gon-.\
# tion thimeed fo\'92s w to lowertonglrilloferinowhoullove-\
# \
# \
#             t s44 ch hr ce degares nngr chenglove tor thingtut  on f{catumatenstvanumunookes oncere, jngby wochsepaiventjoussroll-mestor;eresingt-thing,\
# t thy tolleocheatearesinging maththanethy sofr pilgon, re,\
# thy cepard bu
# ----- diversity: 1.2
# ----- Generating with seed: "r so destroys it:\
#   no love toward othe"
# r so destroys it:\
#   no love toward other thoulteaw?\
#   ou on7by andoreaomu dglithafgexsiifpprtorf,\
# s nn oeme cher oove topate somakethtt awcor,\or ,\
# austonow-gnyea:\
# te thy glfany or teatny grtinht nong, chame buthichengemuthero9swanliwepuri,bind fat, but thenthyes dethr bineombuthinterrecier by gotof fofetilg, pftind\ thy beseresitleameeleswrer vilt ba demere aerifthin\, ongasnormeroneauprasd,\
# hureete,\tnmthrucejonfy loicreie,\
# thy
# 2352/2352 [==============================] - 62s 27ms/sample - loss: 1.7489
# Epoch 10/10
# 2304/2352 [============================>.] - ETA: 0s - loss: 1.6128
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "lusty days;\
# to say, within thine own de"
# lusty days;\
# to say, within thine own de thou re, tor thou no thou thou re,\
# thou re,\
# thou whou re thou ro the dor no be nof thou re,\
# thou me to be and matt toou thou ro thou for chou ro thou re thou no mome tounder thou re,\
# thou re,\
# thou not be nof the dore tound co nom me tor thou ro lovert thou no be thou restre to thou re thou for thou rome tor bet beante art dound thou ro thou re thou no be toor thou ro le douthe tor thou thou
# ----- diversity: 0.5
# ----- Generating with seed: "lusty days;\
# to say, within thine own de"
# lusty days;\
# to say, within thine own de tor bet thou no mere tounde to forent ouer thou whof thou ro serind th nof be toor be nof moird to thou reant dound\
# thou me toor no frover thou rorer of the houl;\
# dor no thouer sorred to beauty cos rod thou noo be noo le cour do ser,\
# thou no prich whou chous mucer morer sore,\
# thou rere to  oume dounder on thou rowert co ge ind whon fot thou no lfou neld ten of thou no thou no moss riss thou f
# ----- diversity: 1.0
# ----- Generating with seed: "lusty days;\
# to say, within thine own de"
# lusty days;\
# to say, within thine own deets no loovond thom act ifennefary doued dor\
# woet  thouerommmthingore to dithy dode  ou trous\'92st, ilomld tor caster.\
# foundts me denf thon fout suefther ropring of thandtwy bea\'92st mabenoastrow thy dof,\
#  2st bot beang fongend foppreroneld did deld thou sod to the urc:\
#  2\
# t nof tenpco ching,\
# thouerang thing ig\'92s onof foondort nor ind sriftistery mogerisllfourids anun
# ed do: ard\'92st f
# ----- diversity: 1.2
# ----- Generating with seed: "lusty days;\
# to say, within thine own de"
# lusty days;\
# to say, within thine own dele foaty bromgebat;
# \
# \
# \
#   i   o           \
# \
# ghen who leeotor\
# \
# iy mesbrellsef heeppr0\'92s nob,ere, toparl oostoun coth look,\
# torer dt dindest teou'91d uny,\
# aourter\
# \
# ou in\,\rllld\'92stt thofte thou.\
# tobt bein end,\
# swr\'92st44catce\deosgrmivy;\
# eld\'92s guingl migl for, hor tyom\'9dst foacr aut dx1ed oreee thit theed aat goorethpbe,\
# arentur mof thot no foivnre toucidd spdichis
# tio ftre
# 2352/2352 [==============================] - 62s 26ms/sample - loss: 1.6123

# %% [markdown]
# # Resources and Stretch Goals

# %% [markdown]
# ## Stretch goals:
# - Refine the training and generation of text to be able to ask for different genres/styles of Shakespearean text (e.g. plays versus sonnets)
# - Train a classification model that takes text and returns which work of Shakespeare it is most likely to be from
# - Make it more performant! Many possible routes here - lean on Keras, optimize the code, and/or use more resources (AWS, etc.)
# - Revisit the news example from class, and improve it - use categories or tags to refine the model/generation, or train a news classifier
# - Run on bigger, better data
#
# ## Resources:
# - [The Unreasonable Effectiveness of Recurrent Neural Networks](https://karpathy.github.io/2015/05/21/rnn-effectiveness/) - a seminal writeup demonstrating a simple but effective character-level NLP RNN
# - [Simple NumPy implementation of RNN](https://github.com/JY-Yoon/RNN-Implementation-using-NumPy/blob/master/RNN%20Implementation%20using%20NumPy.ipynb) - Python 3 version of the code from "Unreasonable Effectiveness"
# - [TensorFlow RNN Tutorial](https://github.com/tensorflow/models/tree/master/tutorials/rnn) - code for training a RNN on the Penn Tree Bank language dataset
# - [4 part tutorial on RNN](http://www.wildml.com/2015/09/recurrent-neural-networks-tutorial-part-1-introduction-to-rnns/) - relates RNN to the vanishing gradient problem, and provides example implementation
# - [RNN training tips and tricks](https://github.com/karpathy/char-rnn#tips-and-tricks) - some rules of thumb for parameterizing and training your RNN
